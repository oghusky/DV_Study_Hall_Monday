# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./Resources/pokemon_data.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
names = df["Name"]
names.head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
above_790 = df[790:]
above_790
# Out:
#        #                 Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790  714               Noibat   Flying  Dragon   40      30       35       45
# 791  715              Noivern   Flying  Dragon   85      70       80       97
# 792  716              Xerneas    Fairy     NaN  126     131       95      131
# 793  717              Yveltal     Dark  Flying  126     131       95      131
# 794  718     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795  719              Diancie     Rock   Fairy   50     100      150      100
# 796  719  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799  721            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# ...

# %%
below_20 = df[:20]
below_20
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# ...

# %%
from_1_to_9 = df[1:9]
from_1_to_9
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# ...

# %%
df.iloc[6]
# Out:
# #                     6
# Name          Charizard
# Type 1             Fire
# Type 2           Flying
# HP                   78
# Attack               84
# Defense              78
# Sp. Atk             109
# Sp. Def              85
# Speed               100
# Generation            1
# Legendary         False
# Name: 6, dtype: object

# %%
for index, row in df.iterrows():
    if(index < 5):
        print(index, row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# ...

# %%
grass_type = df.loc[df["Type 1"] == "Grass"]
grass_type
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
gap = df.loc[(df["Type 1"] == "Grass") & (df["Type 2"]=="Poison") & (df["Attack"] < 80)]
# gap

# %%
# gap.sort_values("Name")
gap.sort_values("Name", ascending=False)
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 452  407    Roserade  Grass  Poison  60      70       65      125      105
# 344  315     Roselia  Grass  Poison  50      60       45      100       80
# 48    43      Oddish  Grass  Poison  45      50       55       75       65
# 1      2     Ivysaur  Grass  Poison  60      62       63       80       80
# 49    44       Gloom  Grass  Poison  60      65       70       85       75
# 651  590     Foongus  Grass  Poison  69      55       45       55       55
# 0      1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 451  406       Budew  Grass  Poison  40      30       35       50       70
# 75    69  Bellsprout  Grass  Poison  50      75       35       70       30
#
#      Speed  Generation  Legendary
# 452     90           4      False
# 344     65           3      False
# 48      30           1      False
# 1       60           1      False
# 49      40           1      False
# ...

# %%
gap.sort_values(["Attack", "Speed"])
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 451  406       Budew  Grass  Poison  40      30       35       50       70
# 0      1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 48    43      Oddish  Grass  Poison  45      50       55       75       65
# 651  590     Foongus  Grass  Poison  69      55       45       55       55
# 344  315     Roselia  Grass  Poison  50      60       45      100       80
# 1      2     Ivysaur  Grass  Poison  60      62       63       80       80
# 49    44       Gloom  Grass  Poison  60      65       70       85       75
# 452  407    Roserade  Grass  Poison  60      70       65      125      105
# 75    69  Bellsprout  Grass  Poison  50      75       35       70       30
#
#      Speed  Generation  Legendary
# 451     55           4      False
# 0       45           1      False
# 48      30           1      False
# 651     15           5      False
# 344     65           3      False
# ...

# %%
gap.sort_values(["Attack", "Speed"], ascending=[0,1])
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 75    69  Bellsprout  Grass  Poison  50      75       35       70       30
# 452  407    Roserade  Grass  Poison  60      70       65      125      105
# 49    44       Gloom  Grass  Poison  60      65       70       85       75
# 1      2     Ivysaur  Grass  Poison  60      62       63       80       80
# 344  315     Roselia  Grass  Poison  50      60       45      100       80
# 651  590     Foongus  Grass  Poison  69      55       45       55       55
# 48    43      Oddish  Grass  Poison  45      50       55       75       65
# 0      1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 451  406       Budew  Grass  Poison  40      30       35       50       70
#
#      Speed  Generation  Legendary
# 75      40           1      False
# 452     90           4      False
# 49      40           1      False
# 1       60           1      False
# 344     65           3      False
# ...

# %%
df["Total"] = df["HP"] + df["Attack"] + df["Defense"]+ df["Sp. Atk"]+df["Sp. Def"]+df["Speed"]
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df.drop(columns=["Total"])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df["Total"] = df.iloc[:,4:10].sum(axis=1)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
gap.reset_index()
# Out:
#    index    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      0    1   Bulbasaur  Grass  Poison  45      49       49       65
# 1      1    2     Ivysaur  Grass  Poison  60      62       63       80
# 2     48   43      Oddish  Grass  Poison  45      50       55       75
# 3     49   44       Gloom  Grass  Poison  60      65       70       85
# 4     75   69  Bellsprout  Grass  Poison  50      75       35       70
# 5    344  315     Roselia  Grass  Poison  50      60       45      100
# 6    451  406       Budew  Grass  Poison  40      30       35       50
# 7    452  407    Roserade  Grass  Poison  60      70       65      125
# 8    651  590     Foongus  Grass  Poison  69      55       45       55
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2       65     30           1      False
# 3       75     40           1      False
# 4       30     40           1      False
# ...

# %%
gap.reset_index(drop=True)
# Out:
#      #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 1    2     Ivysaur  Grass  Poison  60      62       63       80       80
# 2   43      Oddish  Grass  Poison  45      50       55       75       65
# 3   44       Gloom  Grass  Poison  60      65       70       85       75
# 4   69  Bellsprout  Grass  Poison  50      75       35       70       30
# 5  315     Roselia  Grass  Poison  50      60       45      100       80
# 6  406       Budew  Grass  Poison  40      30       35       50       70
# 7  407    Roserade  Grass  Poison  60      70       65      125      105
# 8  590     Foongus  Grass  Poison  69      55       45       55       55
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     30           1      False
# 3     40           1      False
# 4     40           1      False
# 5     65           3      False
# ...

# %%
df.loc[df["Name"].str.contains("Mega")].head()
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 12   9    BlastoiseMega Blastoise  Water     NaN  79     103      120
# 19  15      BeedrillMega Beedrill    Bug  Poison  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 3       122      120     80           1      False    625
# 7       130       85    100           1      False    634
# 8       159      115    100           1      False    634
# 12      135      115     78           1      False    630
# 19       15       80    145           1      False    495

# %%
df.loc[~df["Name"].str.contains("Mega")].head()
# Out:
#    #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2     Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3    Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  4  Charmander   Fire     NaN  39      52       43       60       50     65
# 5  5  Charmeleon   Fire     NaN  58      64       58       80       65     80
#
#    Generation  Legendary  Total
# 0           1      False    318
# 1           1      False    405
# 2           1      False    525
# 4           1      False    309
# 5           1      False    405

# %%
import re

# %%
df.loc[df["Type 1"].str.contains("FIRE", flags=re.I, regex=True)].head()
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 4       50     65           1      False    309
# 5       65     80           1      False    405
# 6       85    100           1      False    534
# 7       85    100           1      False    634
# 8      115    100           1      False    634

# %%
df.loc[df["Name"].str.contains("^pi[a-z]*",flags=re.I, regex=True)].head()
# Out:
#      #                 Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 20  16               Pidgey    Normal  Flying  40      45       40       35
# 21  17            Pidgeotto    Normal  Flying  63      60       55       50
# 22  18              Pidgeot    Normal  Flying  83      80       75       70
# 23  18  PidgeotMega Pidgeot    Normal  Flying  83      80       80      135
# 30  25              Pikachu  Electric     NaN  35      55       40       50
#
#     Sp. Def  Speed  Generation  Legendary  Total
# 20       35     56           1      False    251
# 21       50     71           1      False    349
# 22       70    101           1      False    479
# 23       80    121           1      False    579
# 30       50     90           1      False    320

# %%
# df.loc[df["Type 1"] =="Grass", "Type 1"] = "Cow"
# cow_types=df.copy()
# cow_types

# %%
# cow_types.to_csv("./Resources/cow_mod.csv", index=False)

# %%
# df.dropna(subset=["Type 2"], inplace=True) #NaN = not a number
# df

# %%
gap
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0      1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 1      2     Ivysaur  Grass  Poison  60      62       63       80       80
# 48    43      Oddish  Grass  Poison  45      50       55       75       65
# 49    44       Gloom  Grass  Poison  60      65       70       85       75
# 75    69  Bellsprout  Grass  Poison  50      75       35       70       30
# 344  315     Roselia  Grass  Poison  50      60       45      100       80
# 451  406       Budew  Grass  Poison  40      30       35       50       70
# 452  407    Roserade  Grass  Poison  60      70       65      125      105
# 651  590     Foongus  Grass  Poison  69      55       45       55       55
#
#      Speed  Generation  Legendary
# 0       45           1      False
# 1       60           1      False
# 48      30           1      False
# 49      40           1      False
# 75      40           1      False
# ...

# %%
faf = df.loc[(df["Type 1"] == "Fire") & (df["Type 2"]=="Flying")]
faf
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard   Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 158  146                    Moltres   Fire  Flying   90     100       90
# 270  250                      Ho-oh   Fire  Flying  106     130       90
# 730  662                Fletchinder   Fire  Flying   62      73       55
# 731  663                 Talonflame   Fire  Flying   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 6        109       85    100           1      False    534
# 8        159      115    100           1      False    634
# 158      125       85     90           1       True    580
# 270      110      154     90           2       True    680
# 730       56       52     84           6      False    382
# 731       74       69    126           6      False    499

# %%
fire_grass = faf.append(gap,sort=False)

# %%
fire_grass["IsStrong"] = np.where(fire_grass["Attack"]>=75, True, False) 
#if attack higher than 75 print true if not print false
fire_grass
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard   Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 158  146                    Moltres   Fire  Flying   90     100       90
# 270  250                      Ho-oh   Fire  Flying  106     130       90
# 730  662                Fletchinder   Fire  Flying   62      73       55
# 731  663                 Talonflame   Fire  Flying   78      81       71
# 0      1                  Bulbasaur  Grass  Poison   45      49       49
# 1      2                    Ivysaur  Grass  Poison   60      62       63
# 48    43                     Oddish  Grass  Poison   45      50       55
# 49    44                      Gloom  Grass  Poison   60      65       70
# 75    69                 Bellsprout  Grass  Poison   50      75       35
# 344  315                    Roselia  Grass  Poison   50      60       45
# ...

# %%
faf
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard   Fire  Flying   78      84       78
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 158  146                    Moltres   Fire  Flying   90     100       90
# 270  250                      Ho-oh   Fire  Flying  106     130       90
# 730  662                Fletchinder   Fire  Flying   62      73       55
# 731  663                 Talonflame   Fire  Flying   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 6        109       85    100           1      False    534
# 8        159      115    100           1      False    634
# 158      125       85     90           1       True    580
# 270      110      154     90           2       True    680
# 730       56       52     84           6      False    382
# 731       74       69    126           6      False    499

# %%
faf_mean = faf.groupby(["Attack"]).mean()
faf_mean
# Out:
#           #   HP  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  \
# Attack
# 73      662   62       55       56       52     84           6      False
# 81      663   78       71       74       69    126           6      False
# 84        6   78       78      109       85    100           1      False
# 100     146   90       90      125       85     90           1       True
# 104       6   78       78      159      115    100           1      False
# 130     250  106       90      110      154     90           2       True
#
#         Total
# Attack
# 73        382
# 81        499
# 84        534
# 100       580
# 104       634
# 130       680

# %%
faf.groupby(level=0).sum()
# Out:
#        #   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 6      6   78      84       78      109       85    100           1
# 8      6   78     104       78      159      115    100           1
# 158  146   90     100       90      125       85     90           1
# 270  250  106     130       90      110      154     90           2
# 730  662   62      73       55       56       52     84           6
# 731  663   78      81       71       74       69    126           6
#
#      Legendary  Total
# 6        False    534
# 8        False    634
# 158       True    580
# 270       True    680
# 730      False    382
# 731      False    499

# %%
faf.groupby(["Generation"]).mean()
# Out:
#                      #     HP  Attack  Defense  Sp. Atk  Sp. Def       Speed  \
# Generation
# 1            52.666667   82.0    96.0     82.0    131.0     95.0   96.666667
# 2           250.000000  106.0   130.0     90.0    110.0    154.0   90.000000
# 6           662.500000   70.0    77.0     63.0     65.0     60.5  105.000000
#
#             Legendary       Total
# Generation
# 1            0.333333  582.666667
# 2            1.000000  680.000000
# 6            0.000000  440.500000

# %%
faf.groupby(["Legendary"]).mean()
# Out:
#                 #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# Legendary
# False      334.25  74.0    85.5     70.5     99.5    80.25  102.5         3.5
# True       198.00  98.0   115.0     90.0    117.5   119.50   90.0         1.5
#
#             Total
# Legendary
# False      512.25
# True       630.00
